# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib
matplotlib.use("svg")
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
matplotlib.rc("figure", figsize=(6,4))
import pandas as pd

from tfnn import Neural_Net
from mfcc import create_feature, mel_spectrogram
# Out:
# /Users/odatakuma/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
def split_dataset(features, labels, r=0.7, random=True):
    if random:
        p = np.random.permutation(features.shape[0])
    else
        p = np.arange(features.shape[0])
    N = int(features.shape[0] * r)
    x_train = features[p][:N]
    y_train = labels[p][:N]
    x_test = features[p][N:]
    y_test = labels[p][N:]
    return x_train, y_train, x_test, y_test

# %%
dir0 = 'data/male/sober'
dir1 = 'data/male/drunk'
threshold = 0.06
X, y = create_feature(dir0, dir1, 1, threshold, tmax=120, verbose=True)
# Out:
# ts 277 => msp 0.412
# ts 309 => msp 0.414
# ts 310 => msp 0.371
# ts 340 => msp 0.371
# ts 329 => msp 0.456
# ts 308 => msp 0.383
# ts 266 => msp 0.316
# ts 328 => msp 0.390
# ts 342 => msp 0.412
# ts 323 => msp 0.384
# ts 294 => msp 0.354
# ts 293 => msp 0.352
# ts 280 => msp 0.336
# ts 294 => msp 0.310
# ts 302 => msp 0.325
# ts 254 => msp 0.346
# ts 303 => msp 0.290
# ts 332 => msp 0.319
# ts 616 => msp 0.336
# ts 610 => msp 0.366
# ts 535 => msp 0.344
# ts 615 => msp 0.372
# ts 504 => msp 0.367
# ts 1009 => msp 0.360
# ts 312 => msp 0.356
# ts 699 => msp 0.383
# ts 393 => msp 0.346
# ts 695 => msp 0.358
# ts 418 => msp 0.299
# ts 496 => msp 0.337
# ts 386 => msp 0.342
# ts 533 => msp 0.308
# ts 566 => msp 0.290
# ts 343 => msp 0.318
# ts 497 => msp 0.352
# ts 435 => msp 0.366
# ts 186 => msp 0.333
# ts 7885 => msp 0.343
# ts 7999 => msp 0.479
# ts 4765 => msp 0.396
# ts 793 => msp 0.450
# ts 503 => msp 0.447
# ts 3806 => msp 0.269
# ts 7218 => msp 0.228
# ts 8005 => msp 0.277
# ts 5425 => msp 0.203
# ts 7999 => msp 0.406
# ts 7999 => msp 0.287
# ts 7999 => msp 0.524
# ts 7999 => msp 0.461
# ts 7999 => msp 0.466
# ts 670 => msp 0.393
# ts 515 => msp 0.553
# ts 881 => msp 0.423
# ts 7999 => msp 0.245
# ts 1711 => msp 0.219

# %%
print X.shape
print X[y==0].size
print X[y==1].size
# Out:
# (40811, 40)
# 20402
# 20409
# /Users/odatakuma/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 1; dimension is 40 but corresponding boolean dimension is 1
#   from ipykernel import kernelapp as app
# /Users/odatakuma/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 1; dimension is 40 but corresponding boolean dimension is 1
#   app.launch_new_instance()

# %%
plt.plot(range(X.shape[0]), X.mean(axis=1))
plt.show()

# %%
f, t = np.meshgrid(range(X.shape[1]), range(X.shape[0]))
plt.figure(figsize=[10, 3])
plt.pcolormesh(t, f, X)
plt.axis('tight')
plt.show()

# %%
df = pd.DataFrame(columns='nframe hsize1 hsize2 lr reg accuracy'.split())
accuracy = {}
idx = 1

for nframe in xrange(5, 10, 2):
    X, y = create_feature(dir0, dir1, nframe, threshold)
    print "#frame: %d, data_size: %d" %(nframe, X.shape[0])
    X_train, y_train, X_test, y_test = split_dataset(X, y)
    for hsize1 in xrange(3, 6):
        for hsize2 in xrange(2, hsize1):
            print "hsize1: %d, hsize2: %d" %(2**hsize1, 2**hsize2)
            for lr in np.logspace(-3, -2, 2):
                for reg in np.logspace(-3, -2, 2):
                    model = Neural_Net([40*nframe, hsize1, hsize2, 1], regularization=reg)
                    sess = model.do_training(X_train, y_train, epochs=30, learning_rate=lr)
                    accuracy = model.do_eval(sess, X_test, y_test)
                    sess.close()
                    df.loc[idx] = (nframe, 2**hsize1, 2**hsize2, lr, reg, accuracy)
                    idx += 1
                    print "lr: %g, reg: %g, acc: %g" %(lr, reg, accuracy)
# Out:
# #frame: 5, data_size: 42538
# hsize1: 8, hsize2: 4
# lr: 0.001, reg: 0.001, acc: 0
hsize2: 8
# lr: 0.001, reg: 0.001, acc: 0.576897
# lr: 0.001, reg: 0.01, acc: 0.715379
# lr: 0.01, reg: 0.001, acc: 0.819817
# lr: 0.01, reg: 0.01, acc: 0.818776
# hsize1: 32, hsize2: 4
# lr: 0.001, reg: 0.001, acc: 0.679031
# lr: 0.001, reg: 0.01, acc: 0.649744
# lr: 0.01, reg: 0.001, acc: 0.840482
# lr: 0.01, reg: 0.01, acc: 0.797071
# hsize1: 32, hsize2: 8
# lr: 0.001, reg: 0.001, acc: 0.643425
# lr: 0.001, reg: 0.01, acc: 0.728239
# lr: 0.01, reg: 0.001, acc: 0.817438
# lr: 0.01, reg: 0.01, acc: 0.844273
# hsize1: 32, hsize2: 16
# lr: 0.001, reg: 0.001, acc: 0.599643
# lr: 0.001, reg: 0.01, acc: 0.713075
# lr: 0.01, reg: 0.001, acc: 0.806958
# lr: 0.01, reg: 0.01, acc: 0.821229

# %%
df.groupby(['nframe', 'hsize1', 'hsize2'])['accuracy'].max()
# Out:
# nframe  hsize1  hsize2
# 5       8       4         0.799483
#         16      4         0.800031
#                 8         0.806770
#         32      4         0.802460
#                 8         0.783733
#                 16        0.792822
# 7       8       4         0.776523
#         16      4         0.795604
#                 8         0.789650
#         32      4         0.808655
#                 8         0.815982
#                 16        0.785758
# 9       8       4         0.808519
#         16      4         0.792091
#                 8         0.819817
#         32      4         0.840482
#                 8         0.844273
#                 16        0.821229
# Name: accuracy, dtype: float64

# %%
nframe = 9
hsize1 = 32
hsize2 = 8
lr = 0.01
reg = 0.01

X, y = create_feature(dir0, dir1, nframe, threshold)
model = Neural_Net([40*nframe, hsize1, hsize2, 1], regularization=reg)
sess = model.do_training(X, y, epochs=50, learning_rate=lr)
model.do_eval(sess, X, y)
# Out:
# 0.89380491

# %%
from sklearn.metrics import precision_score, recall_score

y_pred, p = model.predict(sess, X)
print precision_score(y, y_pred)
print recall_score(y, y_pred)
# Out:
# 0.921307214709
# 0.859580582873

# %%
plt.figure(figsize=[10, 4])
plt.subplot(121)
plt.hist(p[y == 1])
plt.xlim([0,1])
plt.subplot(122)
plt.hist(p[y == 0])
plt.xlim([0,1])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from nn_features import save_nn_output

save_nn_output(dir0, model, sess, nframe, threshold)
save_nn_output(dir1, model, sess, nframe, threshold)

# %%
df = pd.read_csv(dir_drunk+'/nn_features/M_dqs_buzzed_clear.csv', names=range(400))
df.head()
# Out:
#       0       1       2       3       4       5       6       7       8    \
# 0 -2.1263 -1.9877 -2.1469 -2.1455 -2.6649 -2.2241 -1.8215 -2.1073 -2.2415
# 1 -2.1541 -2.2076 -2.0235 -1.9689 -2.3309 -2.2129 -1.9795 -2.3689 -2.3856
# 2 -2.3204 -2.0736 -2.0520 -1.8772 -2.2378 -1.9688 -1.7916 -1.8452 -2.2963
# 3 -2.0880 -2.0895 -2.0361 -1.9509 -2.2628 -2.3310 -2.2487 -2.2098 -2.2627
# 4 -2.1925 -2.1192 -2.2995 -2.1088 -2.3651 -2.2049 -2.5651 -2.9434 -2.4792
#
#       9     ...       398     399     400     401     402     403     404  \
# 0 -2.1754   ...    0.0000  0.0734  0.0000  0.1068  1.3299  2.5736  2.4585
# 1 -2.1897   ...    0.0152  0.3154  0.0412  0.1364  1.2100  2.3879  2.2231
# 2 -2.3458   ...    0.0509  0.2063  0.0383  0.0661  1.0606  2.5304  2.4184
# 3 -2.1378   ...    0.3580  0.4777  0.1441  0.0782  0.9599  2.3457  2.0957
# 4 -2.5002   ...    0.0110  0.2232  0.0191  0.0856  1.1423  2.5329  2.2943
#
#       405     406     407
# 0  0.1593  1.6501  0.1743
# 1  0.2174  1.4712  0.1093
# 2  0.2294  1.6076  0.1860
# 3  0.2741  1.4518  0.1752
# 4  0.2347  1.5686  0.1633
#
# [5 rows x 408 columns]

# %%
sess.close()
